# %%
from sklearn.model_selection import cross_val_score
from sklearn import tree
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score  # metrics for manual model eval
import mlflow.pyfunc
import mlflow

# %%
tsv1 = pd.read_csv(r'C:\Users\s434037\Desktop\Bachelor\data\labels.tsv', encoding='utf-8', sep='\t') #encoding and sep to read tsv correctly
tsv2 = pd.read_csv(r'C:\Users\s434037\Desktop\Bachelor\data\prostate_stats.tsv', encoding='utf-8', sep='\t') #encoding and sep to read tsv correctly

patient_data = pd.merge(tsv1, tsv2, left_on=['pseudo_id'], right_on=['pid'], how='inner') # merge both dataframes on pseudo_id and pid
print (patient_data)
# Out:
#       pseudo_id  age sex  staging  px     psa  label  pseudo_patid    set  \
# 0         74404   75   M       re   0    0.09      2         14507  train
# 1         29868   64   M  primary   0    5.14      1         66373  train
# 2         97165   80   M       re   0   23.20      1         88006    val
# 3         40327   71   M       re   1    1.80      0         41467  train
# 4         84824   71   M       re   1    1.05      0         50475  train
# ...         ...  ...  ..      ...  ..     ...    ...           ...    ...
# 1199      16860   68   M       re   1    0.44      1         22584  train
# 1200      17064   61   M       re   1  159.00      0         92324  train
# 1201      47224   65   M       re   0    2.58      1         44278  train
# 1202       8041   75   M       re   0   79.00      1         77358  train
# 1203      85148   78   M       re   0   53.91      1         33053  train
#
#         pid  ...  vol_pix       vol_mm3      mean        sd      cx_px  \
# 0     74404  ...      173  14348.573242  2.126407  0.794587   3.130505
# 1     29868  ...      380  31517.097656  2.345558  1.012620  -1.567092
# 2     97165  ...      351  29111.843750  7.197718  6.139901   3.356041
# 3     40327  ...      134  11113.924805  2.292442  0.624569 -10.468979
# 4     84824  ...      192  15924.427734  1.324341  0.416383  -4.569927
# ...     ...  ...      ...           ...       ...       ...        ...
# 1199  16860  ...      157  13021.537109  4.603152  6.414782   2.269355
# 1200  17064  ...       72   3582.996582  1.262617  0.597831  -4.750730
# 1201  47224  ...      253  12590.250000  2.403591  5.675744  -7.720170
# 1202   8041  ...      349  28945.964844  7.526070  4.826182  -1.668870
# 1203  85148  ...      427  35415.265625  2.034626  1.173795  -9.110150
#
#            cy_px        cz_px          cx         cy         cz
# 0     136.985581 -1780.431039   99.030033  86.545672  34.013792
# 1     142.053093 -1780.263737  100.183431  89.140308  29.947253
# 2     143.911340 -1742.382930   98.974657  89.351033  24.723414
# 3     135.096978 -1649.925847  102.369107  86.573023  25.314831
# 4     148.104092 -1715.679680  100.920716  89.766653  29.164064
# ...          ...          ...         ...        ...        ...
# 1199  143.387561 -1421.227012   99.224034  88.989413  50.954598
# 1200  138.054665 -1191.706763  101.048093  86.650032  46.431079
# 1201  161.072559 -1302.287334  101.777178  96.475606  42.404222
# 1202  140.154471 -1304.444142  100.190985  89.054947  30.311172
# 1203  132.170308 -1210.045279  102.018039  83.657187  55.790944
#
# [1204 rows x 24 columns]

# %%
patient_data = pd.read_csv(r'C:\Users\s434037\Desktop\Bachelor\data\labels.tsv', encoding='utf-8', sep='\t') #encoding and sep to read tsv correctly
# Out:
#       pseudo_id  age sex  staging  px     psa  label  pseudo_patid    set
# 0         74404   75   M       re   0    0.09      2         14507  train
# 1         29868   64   M  primary   0    5.14      1         66373  train
# 2         97165   80   M       re   0   23.20      1         88006    val
# 3         40327   71   M       re   1    1.80      0         41467  train
# 4         84824   71   M       re   1    1.05      0         50475  train
# ...         ...  ...  ..      ...  ..     ...    ...           ...    ...
# 1199      16860   68   M       re   1    0.44      1         22584  train
# 1200      17064   61   M       re   1  159.00      0         92324  train
# 1201      47224   65   M       re   0    2.58      1         44278  train
# 1202       8041   75   M       re   0   79.00      1         77358  train
# 1203      85148   78   M       re   0   53.91      1         33053  train
#
# [1204 rows x 9 columns]

# %%
patient_data = patient_data.dropna() # Drop rows with missing values for simplicity 
patient_data = patient_data.drop(columns=['pseudo_id', 'sex', 'pseudo_patid', 'pid', 'cx_px', 'cy_px', 'cz_px', 'cx', 'cy', 'cz']) # Drop patient_id as it's not a feature for prediction
patient_data = patient_data[patient_data.label != 2] # Remove rows with label 2 as these are not relevant for binary classification
patient_data = patient_data[patient_data.psa != 'NA'] # remove rows with no psa value till i find a better solution
patient_data = patient_data[patient_data.staging != 'primary'] # remove rows with primary staging till i find a better solution

patient_data['age'] = patient_data['age'].astype(float) # convert psa to float
patient_data['px'] = patient_data['px'].astype(float) # convert psa to float

patient_data
# Out:
#        age staging   px     psa  label    set       min        max      rmin  \
# 2     80.0      re  0.0   23.20      1    val  0.518298  32.973873  0.842853
# 3     71.0      re  1.0    1.80      0  train  0.908734   4.015200  1.008141
# 4     71.0      re  1.0    1.05      0  train  0.556755   3.191937  0.630540
# 5     67.0      re  1.0    1.47      0    val  0.754733   3.845006  0.776365
# 6     53.0      re  1.0    1.40      0  train  0.407404   7.776496  0.525310
# ...    ...     ...  ...     ...    ...    ...       ...        ...       ...
# 1199  68.0      re  1.0    0.44      1  train  0.374197  34.756958  0.408580
# 1200  61.0      re  1.0  159.00      0  train  0.508026   3.091441  0.508026
# 1201  65.0      re  0.0    2.58      1  train  0.624586  73.843353  0.624586
# 1202  75.0      re  0.0   79.00      1  train  0.655945  23.050591  1.014260
# 1203  78.0      re  0.0   53.91      1  train  0.494521  15.112329  0.830731
#
#            rmax  vol_pix       vol_mm3      mean        sd
# 2     25.833645      351  29111.843750  7.197718  6.139901
# 3      3.949964      134  11113.924805  2.292442  0.624569
# 4      2.483073      192  15924.427734  1.324341  0.416383
# 5      3.736846      149  12358.018555  1.786344  0.642492
# 6      6.671132      254  21066.691406  1.977446  1.426520
# ...         ...      ...           ...       ...       ...
# 1199  31.181149      157  13021.537109  4.603152  6.414782
# 1200   3.091441       72   3582.996582  1.262617  0.597831
# 1201  16.000526      253  12590.250000  2.403591  5.675744
# 1202  19.243502      349  28945.964844  7.526070  4.826182
# 1203   4.470565      427  35415.265625  2.034626  1.173795
#
# [872 rows x 14 columns]

# %%
train_mask = patient_data['set'] == 'train' 
test_mask = patient_data['set'] == 'val'

# %%
X = pd.get_dummies(patient_data.drop("label", axis=1)) # dummies for categorical variables since forest doesn't handle them directly
X.index = patient_data.index
y = patient_data[["label"]].astype(int) # Keeping y as DataFrame for easier handling of set indicators

# %%
X_train, y_train = X[train_mask], y[train_mask]
X_test, y_test = X[test_mask], y[test_mask]
print(f"Train shape: {X_train.columns} {y_train.shape}") #double check proper set splits
# Out:
# Train shape: Index(['age', 'px', 'psa', 'min', 'max', 'rmin', 'rmax', 'vol_pix', 'vol_mm3',
#        'mean', 'sd', 'staging_re', 'set_train', 'set_val'],
#       dtype='object') (706, 1)

# %%
X_train = X_train.drop(columns=['set_train', 'set_val'], errors= 'ignore') # Drop the set indicator columns
X_test = X_test.drop(columns=['set_train', 'set_val'], errors = 'ignore')

print(X_test.shape, X_train.shape)
# Out:
# (166, 12) (706, 12)

# %%
y_test = np.array(y_test).astype(int) # Convert y_test to a NumPy array of strings
y_train = np.array(y_train).astype(int) # Convert y_train to a NumPy array of strings

y_test = y_test.squeeze()
y_train = y_train.squeeze()

# %%
print("Unique labels in y_train:", np.unique(y_train))
print("Unique labels in y_test:", np.unique(y_test))

if X_train.empty or X_test.empty:
    raise ValueError("One of the datasets (train/test) is empty!")
# Out:
# Unique labels in y_train: [0 1]
# Unique labels in y_test: [0 1]

# %%
if len(X_train) != len(y_train):
    print("Mismatch between X_train and y_train lengths!")
    raise SystemExit()
if len(X_test) != len(y_test):
    print("Mismatch between X_test and y_test lengths!")
    raise SystemExit()

# %%
forest_params = {
    "min_weight_fraction_leaf": 0.1,
    "n_estimators": 30,
}

# %%
param_grid = {
    'min_samples_split': [2, 3, 4],
    'min_weight_fraction_leaf': [0.1],
    'min_impurity_decrease': [0.0, 0.01, 0.1],
    'max_leaf_nodes': [None, 10, 20],
    
}

# %%
rf_classifier = RandomForestClassifier(random_state=42)
grid_search = GridSearchCV(estimator=rf_classifier, param_grid=param_grid, cv=5, n_jobs=-1, scoring='f1', error_score='raise')
grid_search.fit(X_train, y_train)
best_params = grid_search.best_params_
best_score = grid_search.best_score_
model = RandomForestClassifier(**best_params)
model = model.fit(X_train, y_train)

# %%
model = RandomForestClassifier(**forest_params) # Initialize the random forest with specified parameters
model = model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 model = RandomForestClassifier(**forest_params) # Initialize the random forest with specified parameters
#       2 model = model.fit(X_train, y_train)
#
# NameError: name 'forest_params' is not defined

# %%
model_path = r"C:/Users/s434037/Desktop/Bachelor/projects/mlruns/480120777834226073/models/m-fa63154747d64c93ab3f4c76ace550db/artifacts"
model = mlflow.sklearn.load_model (model_path)

# %%
model_uri = f"models:/randomForestV1/version-1"
model = mlflow.sklearn.load_model(model_uri)
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[14], line 2
#       1 model_uri = f"models:/randomForestV1/version-1"
# ----> 2 model = mlflow.sklearn.load_model(model_uri)
#
# File c:\Users\s434037\AppData\Local\miniforge3\Lib\site-packages\mlflow\sklearn\__init__.py:652, in load_model(model_uri, dst_path)
#     617 def load_model(model_uri, dst_path=None):
#     618     """
#     619     Load a scikit-learn model from a local file or a run.
#     620
#    (...)    650         predictions = sk_model.predict(pandas_df)
#     651     """
# --> 652     local_model_path = _download_artifact_from_uri(artifact_uri=model_uri, output_path=dst_path)
#     653     flavor_conf = _get_flavor_configuration(model_path=local_model_path, flavor_name=FLAVOR_NAME)
#     654     _add_code_from_conf_to_system_path(local_model_path, flavor_conf)
#
# File c:\Users\s434037\AppData\Local\miniforge3\Lib\site-packages\mlflow\tracking\artifact_utils.py:117, in _download_artifact_from_uri(artifact_uri, output_path, lineage_header_info, tracking_uri, registry_uri)
#     107 """
#     108 Args:
#     109     artifact_uri: The *absolute* URI of the artifact to download.
#    (...)    114     registry_uri: The registry URI to be used when downloading artifacts.
#     115 """
#     116 root_uri, artifact_path = _get_root_uri_and_artifact_path(artifact_uri)
# --> 117 repo = get_artifact_repository(
#     118     artifact_uri=root_uri, tracking_uri=tracking_uri, registry_uri=registry_uri
#     119 )
#     121 try:
#     122     if isinstance(repo, ModelsArtifactRepository):
#
# File c:\Users\s434037\AppData\Local\miniforge3\Lib\site-packages\mlflow\store\artifact\artifact_repository_registry.py:147, in get_artifact_repository(artifact_uri, tracking_uri, registry_uri)
#     128 def get_artifact_repository(
#     129     artifact_uri: str, tracking_uri: str | None = None, registry_uri: str | None = None
#     130 ) -> ArtifactRepository:
#     131     """
#     132     Get an artifact repository from the registry based on the scheme of artifact_uri
#     133
#    (...)    145         requirements.
#     146     """
# --> 147     return _artifact_repository_registry.get_artifact_repository(
#     148         artifact_uri, tracking_uri, registry_uri
#     149     )
#
# File c:\Users\s434037\AppData\Local\miniforge3\Lib\site-packages\mlflow\store\artifact\artifact_repository_registry.py:83, in ArtifactRepositoryRegistry.get_artifact_repository(self, artifact_uri, tracking_uri, registry_uri)
#      78 if repository is None:
#      79     raise MlflowException(
#      80         f"Could not find a registered artifact repository for: {artifact_uri}. "
#      81         f"Currently registered schemes are: {list(self._registry.keys())}"
#      82     )
# ---> 83 return repository(artifact_uri, tracking_uri=tracking_uri, registry_uri=registry_uri)
#
# File c:\Users\s434037\AppData\Local\miniforge3\Lib\site-packages\mlflow\store\artifact\models_artifact_repo.py:83, in ModelsArtifactRepository.__init__(self, artifact_uri, tracking_uri, registry_uri)
#      77     self.model_version = self.repo.model_version
#      78 else:
#      79     (
#      80         self.model_name,
#      81         self.model_version,
#      82         underlying_uri,
# ---> 83     ) = ModelsArtifactRepository._get_model_uri_infos(artifact_uri)
#      84     self.repo = get_artifact_repository(
#      85         underlying_uri, tracking_uri=tracking_uri, registry_uri=registry_uri
#      86     )
#
# File c:\Users\s434037\AppData\Local\miniforge3\Lib\site-packages\mlflow\store\artifact\models_artifact_repo.py:136, in ModelsArtifactRepository._get_model_uri_infos(uri)
#     132 databricks_profile_uri = (
#     133     get_databricks_profile_uri_from_artifact_uri(uri) or mlflow.get_registry_uri()
#     134 )
#     135 client = MlflowClient(registry_uri=databricks_profile_uri)
# --> 136 name_and_version_or_id = get_model_name_and_version(client, uri)
#     137 if len(name_and_version_or_id) == 1:
#     138     name = None
#
# File c:\Users\s434037\AppData\Local\miniforge3\Lib\site-packages\mlflow\store\artifact\utils\models.py:152, in get_model_name_and_version(client, models_uri)
#     150     mv = client.get_model_version_by_alias(model_name, model_alias)
#     151     return model_name, mv.version
# --> 152 return model_name, str(_get_latest_model_version(client, model_name, model_stage))
#
# File c:\Users\s434037\AppData\Local\miniforge3\Lib\site-packages\mlflow\store\artifact\utils\models.py:44, in _get_latest_model_version(client, name, stage)
#      39 def _get_latest_model_version(client, name, stage):
#      40     """
#      41     Returns the latest version of the stage if stage is not None. Otherwise return the latest of all
#      42     versions.
#      43     """
# ---> 44     latest = client.get_latest_versions(name, None if stage is None else [stage])
#      45     if len(latest) == 0:
#      46         stage_str = "" if stage is None else f" and stage '{stage}'"
#
# File c:\Users\s434037\AppData\Local\miniforge3\Lib\site-packages\mlflow\tracking\_model_registry\client.py:195, in ModelRegistryClient.get_latest_versions(self, name, stages)
#     182 def get_latest_versions(self, name, stages=None):
#     183     """Latest version models for each requests stage. If no ``stages`` provided, returns the
#     184     latest version for each stage.
#     185
#    (...)    193
#     194     """
# --> 195     return self.store.get_latest_versions(name, stages)
#
# File c:\Users\s434037\AppData\Local\miniforge3\Lib\site-packages\mlflow\store\model_registry\file_store.py:453, in FileStore.get_latest_versions(self, name, stages)
#     451     expected_stages = {get_canonical_stage(stage) for stage in ALL_STAGES}
#     452 else:
# --> 453     expected_stages = {get_canonical_stage(stage) for stage in stages}
#     454 latest_versions = {}
#     455 for mv in model_versions:
#
# File c:\Users\s434037\AppData\Local\miniforge3\Lib\site-packages\mlflow\entities\model_registry\model_version_stages.py:19, in get_canonical_stage(stage)
#      17 key = stage.lower()
#      18 if key not in _CANONICAL_MAPPING:
# ---> 19     raise MlflowException(
#      20         "Invalid Model Version stage: {}. Value must be one of {}.".format(
#      21             stage, ", ".join(ALL_STAGES)
#      22         ),
#      23         INVALID_PARAMETER_VALUE,
#      24     )
#      25 return _CANONICAL_MAPPING[key]
#
# MlflowException: Invalid Model Version stage: version-1. Value must be one of None, Staging, Production, Archived.

# %%
eval_data= X_test.copy()
eval_data['label']= y_test #create eval data for flow evaluation

# %%
y_pred = model.predict(X_test) # Make predictions on the test set
metrics = {
        "accuracy": accuracy_score(y_test, y_pred),
        "precision": precision_score(y_test, y_pred, average="weighted"), 
        "recall": recall_score(y_test, y_pred, average="weighted"),
        "f1_score": f1_score(y_test, y_pred, average='weighted'),
    }

print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.89      0.81        98
#            1       0.78      0.57      0.66        68
#
#     accuracy                           0.76       166
#    macro avg       0.77      0.73      0.74       166
# weighted avg       0.76      0.76      0.75       166

# %%
print(f"Best parameters: {grid_search.best_params_}")
print(f"Best cross-validation score: {grid_search.best_score_:.3f}")
print(f"Test score: {best_score:.3f}")
# Out:
# Best parameters: {'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.1}
# Best cross-validation score: 0.718
# Test score: 0.718

# %%
result = mlflow.models.evaluate(
    model_path,
    eval_data,
    targets="label",
    model_type="classifier",
)

# Access metrics
print(f"Precision: {result.metrics['precision_score']:.3f}")
print(f"Recall: {result.metrics['recall_score']:.3f}")
print(f"F1 Score: {result.metrics['f1_score']:.3f}")
print(f"ROC AUC: {result.metrics['roc_auc']:.3f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 result = mlflow.models.evaluate(
# ----> 2     model_path,
#       3     eval_data,
#       4     targets="label",
#       5     model_type="classifier",
#       6 )
#       8 # Access metrics
#       9 print(f"Precision: {result.metrics['precision_score']:.3f}")
#
# NameError: name 'model_path' is not defined
